# %% [markdown]
# # HomeVista: Model Training & Ensemble
#
# **Goal:** Train 4 ML models (Random Forest, XGBoost, LightGBM, CatBoost) and create a weighted ensemble.
#
# ## 1. Setup

# %%
import sys
from pathlib import Path

# Add parent directory to path
sys.path.append(str(Path.cwd().parent / 'src'))

from ml import model_training

# Run the training pipeline
model_training.main()
